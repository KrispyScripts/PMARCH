# %% [markdown]
# # Extract content from PMARCH materials
#
# This notebook will load the DOCX and XLSX files from `Newest Material/` and extract text and table previews for use in the website rewrite.

# %%
import zipfile
from pathlib import Path
import re

base = Path('/workspaces/PMARCH/Newest Material')
print('Base:', base)
files = sorted(base.iterdir())
for file in files:
    print(file.name)
